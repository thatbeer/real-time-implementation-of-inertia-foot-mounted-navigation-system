# %%
# from INS_mod import *
from INS import INS
from Init_det_glrt import Init_det_glrt
from func_loaddataset import func_loaddataset
from utils import *

# %%
u = func_loaddataset('./data_inert.txt')

# %%
simdata = Init_det_glrt()
# Variables for calculating the performance
D = len(simdata['data_sets'])
Jadapt = 0
Jadapt_all = np.zeros((D, 3))
gamma_vec = np.logspace(4, 6, 20)
M = len(gamma_vec)
ctr = 1
Niter = M
Jfixed = np.zeros(M)
Jfixed_all = np.zeros((M, D, 3))

ins = INS(simdata)

# %%
zupt , logL = ins.detector_adaptive(u)
x_h, _, _, _ = ins.baseline(u, zupt, logL, True)

# %%
plot_position_tracking(x_h)

# %%
n = 500
num_batches = len(u[0]) // n
for i in range(num_batches+1):
    # print(i)
    ui = u[:, :(i+1)*n]
    zupt , logL = ins.detector_adaptive(ui)
    x_h, _, quat, P = ins.baseline(ui, zupt, logL, True) # 9, N

# %%
plot_position_tracking(x_h)

# %%
n = 5000
num_batches = len(u[0]) // n
state_position = []
xhs = []
init_P = None
init_quat = None
init_position = None
position = np.zeros((3,1))
state_vector = np.zeros((9, 1))
init_position = None
init_P = None
init_quat = None


for i in range(num_batches+1):
    # print(i)
    ui = u[:, i*n:(i+1)*n]
    zupt , logL = ins.detector_adaptive(ui)
    x_h, _, quat, P = ins.baseline(ui, zupt, logL, True, init_position, init_quat) # 9, N
    # x, y, z = x_h[0:3, -1]
    # position[0] += x
    # position[1] += y
    # position[2] += z
    # state_position.append(position.ravel().tolist())
    init_position = x_h[0:9, -1]
    init_quat = quat
    init_P = P
    # for k in range(len(x_h[0])):
    #     xhs.append(list(x_h[:,k]))

# %%
plot_position_tracking(x_h)

# %% [markdown]
# ### test batch processing

# %%
n = 2000
num_batches = len(u[0]) // n
state_position = []
xhs = []
init_P = None
init_quat = None
init_position = None
position = np.zeros((3,1))
state_vector = np.zeros((9, 1))
init_position = None
init_P = None
init_quat = None

# %%
batch1 = u[:, i*n:(i+1)*n]

# %%
zupt , logL = ins.detector_adaptive(ui)
x_h, _, quat, P = ins.baseline(ui, zupt, logL, True)

# %%
plot_position_tracking(x_h)
